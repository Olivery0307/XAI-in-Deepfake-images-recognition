# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os

# Get the current working directory (where the notebook is running)
current_dir = os.getcwd()

# Get the parent directory (project root)
project_root = "/content/drive/MyDrive/Computer_Vision/XAI-in-Deepfake-images-recognition/"

# 3. Change the working directory
try:
    os.chdir(project_root)
    print(f"✅ Changed working directory to: {os.getcwd()}")
except FileNotFoundError:
    print(f"❌ Error: Could not find directory: {project_root}")
    print("Please check the path in your Google Drive.")

# 4. Add the project root to sys.path
# This ensures imports like 'from src.data_loader import ...' work correctly.
if project_root not in sys.path:
    sys.path.append(project_root)
    print(f"Added '{project_root}' to sys.path")
# Out:
# ✅ Changed working directory to: /content/drive/MyDrive/Computer_Vision/XAI-in-Deepfake-images-recognition

# %%
# !pip install -q -r requirements.txt

# %%
# 1. Install the ngrok python wrapper
# !pip install pyngrok

# %%
from pyngrok import ngrok

# 2. Authenticate (Paste your token below)
# Important: Keep this token private if you are sharing this notebook!
ngrok.set_auth_token("ngrok_api")

# 3. Run Streamlit in the background
# We use 'nohup' (no hang up) to keep the process running even if we move to the next cell
# !nohup streamlit run app.py --server.port 8501 &

# 4. Open the Tunnel
# This creates the public URL that forwards to your Colab's localhost:8501
public_url = ngrok.connect(8501).public_url

print(f"Your public Streamlit URL is: {public_url}")
# Out:
# nohup: appending output to 'nohup.out'
# Your public Streamlit URL is: https://ean-unwholesome-antonina.ngrok-free.dev

# %%
# !pkill -f streamlit

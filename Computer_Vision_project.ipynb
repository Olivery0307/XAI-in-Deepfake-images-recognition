# %% [markdown]
# <a href="https://colab.research.google.com/github/Olivery0307/XAI-in-Deepfake-images-recognition/blob/Joshua_Branch/Computer_Vision_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
